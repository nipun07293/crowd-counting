# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# Out:
# Mounted at /content/drive
# /content

# %%
import os
import numpy as np
from scipy.io import loadmat
from scipy.ndimage import gaussian_filter
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.models import vit_b_16, ViT_B_16_Weights
from torch.optim.lr_scheduler import CosineAnnealingLR
from collections import OrderedDict
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.switch_backend('Agg')

def _find_points_in_mat(obj, current_path=""):
    if isinstance(obj, np.ndarray) and obj.ndim == 2 and obj.shape[1] == 2:
        return obj
    if isinstance(obj, dict):
        for key, value in obj.items():
            result = _find_points_in_mat(value, f"{current_path}.{key}" if current_path else key)
            if result is not None:
                return result
    if isinstance(obj, np.void) and obj.dtype.fields is not None:
        for field_name in obj.dtype.fields:
            field_value = obj[field_name]
            if field_value.ndim > 0 and field_value.size > 0 and isinstance(field_value.item(0), np.void):
                for item in field_value.flatten():
                    result = _find_points_in_mat(item, f"{current_path}.{field_name}")
                    if result is not None:
                        return result
            else:
                result = _find_points_in_mat(field_value, f"{current_path}.{field_name}")
                if result is not None:
                    return result
    if isinstance(obj, np.ndarray) and obj.dtype == object:
        for item in obj.flatten():
            result = _find_points_in_mat(item, current_path)
            if result is not None:
                return result
    return None

def generate_density_map(img_path, mat_path, sigma=4):
    img = Image.open(img_path).convert('RGB')
    w, h = img.size
    density = np.zeros((h, w), dtype=np.float32)
    try:
        mat = loadmat(mat_path)
        points = None
        if 'annPoints' in mat:
            points = mat['annPoints']
        elif 'image_info' in mat:
            info = mat['image_info']
            if info.ndim > 0 and info.shape[0] > 0 and info.shape[1] > 0:
                first_info_elem = info[0, 0]
                if 'location' in first_info_elem.dtype.names:
                    points = first_info_elem['location']
                elif 'number' in first_info_elem.dtype.names and 'location' in first_info_elem.dtype.names:
                    points = first_info_elem['location']
        if points is None:
            points = _find_points_in_mat(mat)
        if not (isinstance(points, np.ndarray) and points.ndim == 2 and points.shape[1] == 2):
            raise ValueError("")
        if points.size == 0:
            return gaussian_filter(density, sigma=sigma)
        for x_raw, y_raw in points:
            x, y = int(round(x_raw)), int(round(y_raw))
            if 0 <= x < w and 0 <= y < h:
                density[y, x] += 1
        return gaussian_filter(density, sigma=sigma)
    except Exception as e:
        raise ValueError(f" {mat_path}: {e}")

def preprocess_dataset(img_dir, mat_dir, out_dir, sigma=4):
    os.makedirs(out_dir, exist_ok=True)
    image_files = sorted([f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
    processed_count, skipped_count = 0, 0
    skipped_file_details = []
    for fname in image_files:
        img_path = os.path.join(img_dir, fname)
        mat_fname = 'GT_' + os.path.splitext(fname)[0] + '.mat'
        mat_path = os.path.join(mat_dir, mat_fname)
        out_path = os.path.join(out_dir, os.path.splitext(fname)[0] + '.npy')
        if not os.path.isfile(mat_path):
            skipped_file_details.append(f"{fname}: ")
            skipped_count += 1
            continue
        try:
            dm = generate_density_map(img_path, mat_path, sigma)
            np.save(out_path, dm)
            processed_count += 1
        except ValueError as e:
            skipped_file_details.append(f"{fname}: {e}")
            skipped_count += 1
    print(f"Finished preprocessing for {img_dir}. skipped: {processed_count}, Success: {skipped_count}")
    if skipped_count > 0:
        for detail in skipped_file_details:
            print(f"- {detail}")

class CrowdDataset(Dataset):
    def __init__(self, img_dir, dm_dir, transform=None):
        self.img_dir, self.dm_dir, self.transform = img_dir, dm_dir, transform
        self.files = [f for f in sorted(os.listdir(img_dir)) if os.path.exists(os.path.join(dm_dir, os.path.splitext(f)[0] + '.npy'))]
        if not self.files:
            raise FileNotFoundError(f"No matching files found in {img_dir} and {dm_dir}.")
    def __len__(self):
        return len(self.files)
    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir, name)).convert('RGB')
        dm = np.load(os.path.join(self.dm_dir, os.path.splitext(name)[0] + '.npy'))
        original_img = img.copy()
        original_dm_sum = np.sum(dm)
        if self.transform:
            img = self.transform(img)
            dm_tensor = torch.from_numpy(dm).unsqueeze(0).unsqueeze(0)
            dm_resized = F.interpolate(dm_tensor, size=img.shape[1:], mode='bilinear', align_corners=False).squeeze(0)
            if original_dm_sum > 0:
                resized_sum = torch.sum(dm_resized)
                if resized_sum > 0:
                    dm_resized *= (original_dm_sum / resized_sum)
            dm = dm_resized
        else:
            dm = torch.from_numpy(dm).unsqueeze(0)
        return img, dm, original_img, name

def custom_collate_fn(batch):
    imgs = torch.stack([item[0] for item in batch], 0)
    dms = torch.stack([item[1] for item in batch], 0)
    original_imgs = [item[2] for item in batch]
    names = [item[3] for item in batch]
    return imgs, dms, original_imgs, names

class CCTrans(nn.Module):
    def __init__(self, img_size=(384, 384), patch_size=16, vit_out_channels=768):
        super().__init__()
        self.vit = vit_b_16(weights=ViT_B_16_Weights.IMAGENET1K_SWAG_E2E_V1)
        self.vit.heads = nn.Identity()
        self.grid_h, self.grid_w = img_size[0] // patch_size, img_size[1] // patch_size
        self.features = OrderedDict()
        self.vit.conv_proj.register_forward_hook(self._get_features_hook('patch_embed'))
        self.vit.encoder.layers[5].register_forward_hook(self._get_features_hook('block_6'))
        self.vit.encoder.layers[-1].register_forward_hook(self._get_features_hook('block_last'))
        self.conv_adapt_high = nn.Conv2d(vit_out_channels, 256, 1)
        self.conv_adapt_mid = nn.Conv2d(vit_out_channels, 256, 1)
        self.conv_adapt_low = nn.Conv2d(vit_out_channels, 256, 1)
        self.decoder_up1 = nn.Sequential(nn.ConvTranspose2d(256, 128, 2, 2), nn.ReLU(True), nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(True))
        self.fuse1 = nn.Sequential(nn.Conv2d(128 + 256, 128, 1), nn.ReLU(True), nn.Conv2d(128, 128, 3, padding=2, dilation=2), nn.ReLU(True))
        self.decoder_up2 = nn.Sequential(nn.ConvTranspose2d(128, 64, 2, 2), nn.ReLU(True), nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(True))
        self.fuse2 = nn.Sequential(nn.Conv2d(64 + 256, 64, 1), nn.ReLU(True), nn.Conv2d(64, 64, 3, padding=3, dilation=3), nn.ReLU(True))
        self.decoder_up3 = nn.Sequential(nn.ConvTranspose2d(64, 32, 2, 2), nn.ReLU(True), nn.Conv2d(32, 32, 3, padding=1), nn.ReLU(True))
        self.decoder_up4 = nn.Sequential(nn.ConvTranspose2d(32, 16, 2, 2), nn.ReLU(True), nn.Conv2d(16, 16, 3, padding=1), nn.ReLU(True))
        self.output_layer = nn.Conv2d(16, 1, kernel_size=1)
        self._initialize_decoder_weights()
    def _initialize_decoder_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)) and m not in self.vit.modules():
                nn.init.normal_(m.weight, std=0.01)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
    def _get_features_hook(self, name):
        def hook(_, __, output):
            if name == 'patch_embed':
                self.features[name] = output
            elif output.ndim == 3:
                self.features[name] = output[:, 1:].permute(0, 2, 1).reshape(output.size(0), -1, self.grid_h, self.grid_w)
        return hook
    def forward(self, x):
        original_size = x.shape[2:]
        self.features.clear()
        _ = self.vit(x)
        f_last = self.conv_adapt_low(self.features['block_last'])
        d1 = self.decoder_up1(f_last)
        f_mid = F.interpolate(self.features['block_6'], size=d1.shape[2:], mode='bilinear')
        d1_fused = self.fuse1(torch.cat([d1, self.conv_adapt_mid(f_mid)], dim=1))
        d2 = self.decoder_up2(d1_fused)
        f_patch = F.interpolate(self.features['patch_embed'], size=d2.shape[2:], mode='bilinear')
        d2_fused = self.fuse2(torch.cat([d2, self.conv_adapt_high(f_patch)], dim=1))
        d3 = self.decoder_up3(d2_fused)
        d4 = self.decoder_up4(d3)
        density_map = self.output_layer(d4)
        return F.relu(F.interpolate(density_map, size=original_size, mode='bilinear'))

def train_model(loader, model, criterion, optimizer, scheduler, device, epochs):
    model.to(device)
    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        for i, (imgs, dms, _, _) in enumerate(loader):
            imgs, dms = imgs.to(device), dms.to(device)
            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, dms)
            if torch.isnan(loss) or torch.isinf(loss):
                continue
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        scheduler.step()

def evaluate_model(loader, model, device, output_vis_dir=None, max_vis_images=20):
    model.to(device)
    model.eval()
    mae, mse, vis_count = 0.0, 0.0, 0
    if output_vis_dir:
        os.makedirs(output_vis_dir, exist_ok=True)
    with torch.no_grad():
        for imgs, dms, original_imgs, names in loader:
            preds = F.relu(model(imgs.to(device)))
            pred_counts = preds.sum(dim=[1, 2, 3]).cpu()
            gt_counts = dms.sum(dim=[1, 2, 3])
            mae += (pred_counts - gt_counts).abs().sum().item()
            mse += ((pred_counts - gt_counts) ** 2).sum().item()
    total = len(loader.dataset)
    print(f"MAE: {mae/total:.2f}, RMSE: {np.sqrt(mse/total):.2f}")

def save_density_map_visualization(img, gt, pred, path, name):
    fig, axes = plt.subplots(1, 3, figsize=(20, 7))
    vmax = max(gt.max(), pred.max(), 0.1)
    axes[0].imshow(img); axes[0].set_title(f'Original: {name}'); axes[0].axis('off')
    axes[1].imshow(gt, cmap='jet', vmin=0, vmax=vmax); axes[1].set_title(f'GT Count: {gt.sum():.2f}'); axes[1].axis('off')
    axes[2].imshow(pred, cmap='jet', vmin=0, vmax=vmax); axes[2].set_title(f'Pred Count: {pred.sum():.2f}'); axes[2].axis('off')
    plt.tight_layout()
    plt.savefig(path)
    plt.close(fig)

if __name__ == '__main__':
    train_images = '/content/drive/MyDrive/images'
    train_gt = '/content/drive/MyDrive/ground_truth'
    train_dm = '/content/drive/MyDrive/density_maps'
    test_images = '/content/drive/MyDrive/images1'
    test_gt = '/content/drive/MyDrive/ground_truth1'
    test_dm = '/content/drive/MyDrive/density_maps1'
    visualization_output_dir = '/content/drive/MyDrive/cctrans3_visualizations'
    PRETRAINED_WEIGHTS_PATH = '/content/drive/MyDrive/alt_gvt_large.pth'
    IMG_SIZE, PATCH_SIZE, EPOCHS, BATCH_SIZE = (384, 384), 16, 10, 4
    preprocess_dataset(train_images, train_gt, train_dm)
    preprocess_dataset(test_images, test_gt, test_dm)
    transform = {
        'train': transforms.Compose([
            transforms.Resize(IMG_SIZE),
            transforms.RandomHorizontalFlip(),
            transforms.ColorJitter(brightness=0.1, contrast=0.1),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'test': transforms.Compose([
            transforms.Resize(IMG_SIZE),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])
    }
    train_dataset = CrowdDataset(train_images, train_dm, transform['train'])
    test_dataset = CrowdDataset(test_images, test_dm, transform['test'])
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, collate_fn=custom_collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=2, collate_fn=custom_collate_fn)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = CCTrans(img_size=IMG_SIZE)
    if os.path.exists(PRETRAINED_WEIGHTS_PATH):
        model.vit.load_state_dict(torch.load(PRETRAINED_WEIGHTS_PATH, map_location=device), strict=False)
    decoder_params = [p for n, p in model.named_parameters() if 'vit' not in n and p.requires_grad]
    backbone_params = [p for n, p in model.named_parameters() if 'vit' in n and p.requires_grad]
    optimizer = torch.optim.AdamW([
        {'params': backbone_params, 'lr': 1e-6},
        {'params': decoder_params, 'lr': 1e-5}
    ], weight_decay=1e-4)
    criterion = nn.MSELoss()
    scheduler = CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-7)
    train_model(train_loader, model, criterion, optimizer, scheduler, device, epochs=EPOCHS)
    evaluate_model(test_loader, model, device, output_vis_dir=visualization_output_dir)
# Out:
# Finished preprocessing for /content/drive/MyDrive/images. skipped: 0, Success: 400
# - IMG_1.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_1.mat:
# - IMG_10.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_10.mat:
# - IMG_100.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_100.mat:
# - IMG_101.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_101.mat:
# - IMG_102.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_102.mat:
# - IMG_103.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_103.mat:
# - IMG_104.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_104.mat:
# - IMG_105.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_105.mat:
# - IMG_106.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_106.mat:
# - IMG_107.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_107.mat:
# - IMG_108.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_108.mat:
# - IMG_109.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_109.mat:
# - IMG_11.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_11.mat:
# - IMG_110.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_110.mat:
# - IMG_111.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_111.mat:
# - IMG_112.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_112.mat:
# - IMG_113.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_113.mat:
# - IMG_114.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_114.mat:
# - IMG_115.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_115.mat:
# - IMG_116.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_116.mat:
# - IMG_117.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_117.mat:
# - IMG_118.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_118.mat:
# - IMG_119.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_119.mat:
# - IMG_12.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_12.mat:
# - IMG_120.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_120.mat:
# - IMG_121.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_121.mat:
# - IMG_122.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_122.mat:
# - IMG_123.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_123.mat:
# - IMG_124.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_124.mat:
# - IMG_125.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_125.mat:
# - IMG_126.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_126.mat:
# - IMG_127.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_127.mat:
# - IMG_128.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_128.mat:
# - IMG_129.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_129.mat:
# - IMG_13.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_13.mat:
# - IMG_130.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_130.mat:
# - IMG_131.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_131.mat:
# - IMG_132.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_132.mat:
# - IMG_133.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_133.mat:
# - IMG_134.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_134.mat:
# - IMG_135.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_135.mat:
# - IMG_136.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_136.mat:
# - IMG_137.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_137.mat:
# - IMG_138.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_138.mat:
# - IMG_139.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_139.mat:
# - IMG_14.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_14.mat:
# - IMG_140.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_140.mat:
# - IMG_141.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_141.mat:
# - IMG_142.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_142.mat:
# - IMG_143.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_143.mat:
# - IMG_144.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_144.mat:
# - IMG_145.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_145.mat:
# - IMG_146.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_146.mat:
# - IMG_147.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_147.mat:
# - IMG_148.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_148.mat:
# - IMG_149.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_149.mat:
# - IMG_15.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_15.mat:
# - IMG_150.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_150.mat:
# - IMG_151.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_151.mat:
# - IMG_152.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_152.mat:
# - IMG_153.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_153.mat:
# - IMG_154.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_154.mat:
# - IMG_155.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_155.mat:
# - IMG_156.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_156.mat:
# - IMG_157.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_157.mat:
# - IMG_158.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_158.mat:
# - IMG_159.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_159.mat:
# - IMG_16.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_16.mat:
# - IMG_160.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_160.mat:
# - IMG_161.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_161.mat:
# - IMG_162.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_162.mat:
# - IMG_163.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_163.mat:
# - IMG_164.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_164.mat:
# - IMG_165.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_165.mat:
# - IMG_166.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_166.mat:
# - IMG_167.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_167.mat:
# - IMG_168.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_168.mat:
# - IMG_169.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_169.mat:
# - IMG_17.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_17.mat:
# - IMG_170.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_170.mat:
# - IMG_171.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_171.mat:
# - IMG_172.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_172.mat:
# - IMG_173.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_173.mat:
# - IMG_174.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_174.mat:
# - IMG_175.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_175.mat:
# - IMG_176.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_176.mat:
# - IMG_177.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_177.mat:
# - IMG_178.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_178.mat:
# - IMG_179.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_179.mat:
# - IMG_18.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_18.mat:
# - IMG_180.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_180.mat:
# - IMG_181.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_181.mat:
# - IMG_182.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_182.mat:
# - IMG_183.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_183.mat:
# - IMG_184.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_184.mat:
# - IMG_185.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_185.mat:
# - IMG_186.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_186.mat:
# - IMG_187.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_187.mat:
# - IMG_188.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_188.mat:
# - IMG_189.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_189.mat:
# - IMG_19.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_19.mat:
# - IMG_190.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_190.mat:
# - IMG_191.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_191.mat:
# - IMG_192.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_192.mat:
# - IMG_193.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_193.mat:
# - IMG_194.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_194.mat:
# - IMG_195.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_195.mat:
# - IMG_196.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_196.mat:
# - IMG_197.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_197.mat:
# - IMG_198.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_198.mat:
# - IMG_199.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_199.mat:
# - IMG_2.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_2.mat:
# - IMG_20.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_20.mat:
# - IMG_200.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_200.mat:
# - IMG_201.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_201.mat:
# - IMG_202.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_202.mat:
# - IMG_203.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_203.mat:
# - IMG_204.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_204.mat:
# - IMG_205.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_205.mat:
# - IMG_206.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_206.mat:
# - IMG_207.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_207.mat:
# - IMG_208.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_208.mat:
# - IMG_209.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_209.mat:
# - IMG_21.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_21.mat:
# - IMG_210.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_210.mat:
# - IMG_211.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_211.mat:
# - IMG_212.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_212.mat:
# - IMG_213.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_213.mat:
# - IMG_214.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_214.mat:
# - IMG_215.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_215.mat:
# - IMG_216.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_216.mat:
# - IMG_217.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_217.mat:
# - IMG_218.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_218.mat:
# - IMG_219.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_219.mat:
# - IMG_22.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_22.mat:
# - IMG_220.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_220.mat:
# - IMG_221.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_221.mat:
# - IMG_222.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_222.mat:
# - IMG_223.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_223.mat:
# - IMG_224.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_224.mat:
# - IMG_225.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_225.mat:
# - IMG_226.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_226.mat:
# - IMG_227.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_227.mat:
# - IMG_228.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_228.mat:
# - IMG_229.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_229.mat:
# - IMG_23.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_23.mat:
# - IMG_230.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_230.mat:
# - IMG_231.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_231.mat:
# - IMG_232.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_232.mat:
# - IMG_233.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_233.mat:
# - IMG_234.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_234.mat:
# - IMG_235.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_235.mat:
# - IMG_236.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_236.mat:
# - IMG_237.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_237.mat:
# - IMG_238.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_238.mat:
# - IMG_239.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_239.mat:
# - IMG_24.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_24.mat:
# - IMG_240.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_240.mat:
# - IMG_241.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_241.mat:
# - IMG_242.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_242.mat:
# - IMG_243.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_243.mat:
# - IMG_244.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_244.mat:
# - IMG_245.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_245.mat:
# - IMG_246.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_246.mat:
# - IMG_247.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_247.mat:
# - IMG_248.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_248.mat:
# - IMG_249.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_249.mat:
# - IMG_25.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_25.mat:
# - IMG_250.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_250.mat:
# - IMG_251.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_251.mat:
# - IMG_252.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_252.mat:
# - IMG_253.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_253.mat:
# - IMG_254.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_254.mat:
# - IMG_255.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_255.mat:
# - IMG_256.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_256.mat:
# - IMG_257.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_257.mat:
# - IMG_258.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_258.mat:
# - IMG_259.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_259.mat:
# - IMG_26.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_26.mat:
# - IMG_260.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_260.mat:
# - IMG_261.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_261.mat:
# - IMG_262.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_262.mat:
# - IMG_263.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_263.mat:
# - IMG_264.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_264.mat:
# - IMG_265.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_265.mat:
# - IMG_266.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_266.mat:
# - IMG_267.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_267.mat:
# - IMG_268.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_268.mat:
# - IMG_269.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_269.mat:
# - IMG_27.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_27.mat:
# - IMG_270.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_270.mat:
# - IMG_271.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_271.mat:
# - IMG_272.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_272.mat:
# - IMG_273.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_273.mat:
# - IMG_274.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_274.mat:
# - IMG_275.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_275.mat:
# - IMG_276.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_276.mat:
# - IMG_277.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_277.mat:
# - IMG_278.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_278.mat:
# - IMG_279.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_279.mat:
# - IMG_28.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_28.mat:
# - IMG_280.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_280.mat:
# - IMG_281.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_281.mat:
# - IMG_282.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_282.mat:
# - IMG_283.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_283.mat:
# - IMG_284.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_284.mat:
# - IMG_285.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_285.mat:
# - IMG_286.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_286.mat:
# - IMG_287.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_287.mat:
# - IMG_288.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_288.mat:
# - IMG_289.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_289.mat:
# - IMG_29.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_29.mat:
# - IMG_290.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_290.mat:
# - IMG_291.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_291.mat:
# - IMG_292.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_292.mat:
# - IMG_293.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_293.mat:
# - IMG_294.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_294.mat:
# - IMG_295.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_295.mat:
# - IMG_296.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_296.mat:
# - IMG_297.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_297.mat:
# - IMG_298.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_298.mat:
# - IMG_299.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_299.mat:
# - IMG_3.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_3.mat:
# - IMG_30.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_30.mat:
# - IMG_300.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_300.mat:
# - IMG_301.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_301.mat:
# - IMG_302.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_302.mat:
# - IMG_303.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_303.mat:
# - IMG_304.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_304.mat:
# - IMG_305.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_305.mat:
# - IMG_306.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_306.mat:
# - IMG_307.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_307.mat:
# - IMG_308.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_308.mat:
# - IMG_309.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_309.mat:
# - IMG_31.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_31.mat:
# - IMG_310.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_310.mat:
# - IMG_311.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_311.mat:
# - IMG_312.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_312.mat:
# - IMG_313.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_313.mat:
# - IMG_314.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_314.mat:
# - IMG_315.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_315.mat:
# - IMG_316.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_316.mat:
# - IMG_317.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_317.mat:
# - IMG_318.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_318.mat:
# - IMG_319.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_319.mat:
# - IMG_32.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_32.mat:
# - IMG_320.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_320.mat:
# - IMG_321.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_321.mat:
# - IMG_322.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_322.mat:
# - IMG_323.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_323.mat:
# - IMG_324.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_324.mat:
# - IMG_325.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_325.mat:
# - IMG_326.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_326.mat:
# - IMG_327.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_327.mat:
# - IMG_328.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_328.mat:
# - IMG_329.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_329.mat:
# - IMG_33.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_33.mat:
# - IMG_330.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_330.mat:
# - IMG_331.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_331.mat:
# - IMG_332.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_332.mat:
# - IMG_333.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_333.mat:
# - IMG_334.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_334.mat:
# - IMG_335.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_335.mat:
# - IMG_336.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_336.mat:
# - IMG_337.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_337.mat:
# - IMG_338.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_338.mat:
# - IMG_339.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_339.mat:
# - IMG_34.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_34.mat:
# - IMG_340.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_340.mat:
# - IMG_341.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_341.mat:
# - IMG_342.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_342.mat:
# - IMG_343.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_343.mat:
# - IMG_344.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_344.mat:
# - IMG_345.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_345.mat:
# - IMG_346.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_346.mat:
# - IMG_347.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_347.mat:
# - IMG_348.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_348.mat:
# - IMG_349.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_349.mat:
# - IMG_35.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_35.mat:
# - IMG_350.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_350.mat:
# - IMG_351.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_351.mat:
# - IMG_352.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_352.mat:
# - IMG_353.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_353.mat:
# - IMG_354.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_354.mat:
# - IMG_355.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_355.mat:
# - IMG_356.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_356.mat:
# - IMG_357.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_357.mat:
# - IMG_358.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_358.mat:
# - IMG_359.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_359.mat:
# - IMG_36.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_36.mat:
# - IMG_360.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_360.mat:
# - IMG_361.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_361.mat:
# - IMG_362.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_362.mat:
# - IMG_363.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_363.mat:
# - IMG_364.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_364.mat:
# - IMG_365.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_365.mat:
# - IMG_366.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_366.mat:
# - IMG_367.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_367.mat:
# - IMG_368.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_368.mat:
# - IMG_369.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_369.mat:
# - IMG_37.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_37.mat:
# - IMG_370.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_370.mat:
# - IMG_371.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_371.mat:
# - IMG_372.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_372.mat:
# - IMG_373.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_373.mat:
# - IMG_374.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_374.mat:
# - IMG_375.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_375.mat:
# - IMG_376.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_376.mat:
# - IMG_377.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_377.mat:
# - IMG_378.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_378.mat:
# - IMG_379.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_379.mat:
# - IMG_38.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_38.mat:
# - IMG_380.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_380.mat:
# - IMG_381.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_381.mat:
# - IMG_382.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_382.mat:
# - IMG_383.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_383.mat:
# - IMG_384.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_384.mat:
# - IMG_385.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_385.mat:
# - IMG_386.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_386.mat:
# - IMG_387.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_387.mat:
# - IMG_388.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_388.mat:
# - IMG_389.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_389.mat:
# - IMG_39.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_39.mat:
# - IMG_390.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_390.mat:
# - IMG_391.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_391.mat:
# - IMG_392.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_392.mat:
# - IMG_393.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_393.mat:
# - IMG_394.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_394.mat:
# - IMG_395.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_395.mat:
# - IMG_396.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_396.mat:
# - IMG_397.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_397.mat:
# - IMG_398.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_398.mat:
# - IMG_399.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_399.mat:
# - IMG_4.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_4.mat:
# - IMG_40.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_40.mat:
# - IMG_400.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_400.mat:
# - IMG_41.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_41.mat:
# - IMG_42.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_42.mat:
# - IMG_43.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_43.mat:
# - IMG_44.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_44.mat:
# - IMG_45.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_45.mat:
# - IMG_46.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_46.mat:
# - IMG_47.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_47.mat:
# - IMG_48.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_48.mat:
# - IMG_49.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_49.mat:
# - IMG_5.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_5.mat:
# - IMG_50.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_50.mat:
# - IMG_51.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_51.mat:
# - IMG_52.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_52.mat:
# - IMG_53.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_53.mat:
# - IMG_54.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_54.mat:
# - IMG_55.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_55.mat:
# - IMG_56.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_56.mat:
# - IMG_57.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_57.mat:
# - IMG_58.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_58.mat:
# - IMG_59.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_59.mat:
# - IMG_6.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_6.mat:
# - IMG_60.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_60.mat:
# - IMG_61.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_61.mat:
# - IMG_62.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_62.mat:
# - IMG_63.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_63.mat:
# - IMG_64.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_64.mat:
# - IMG_65.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_65.mat:
# - IMG_66.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_66.mat:
# - IMG_67.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_67.mat:
# - IMG_68.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_68.mat:
# - IMG_69.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_69.mat:
# - IMG_7.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_7.mat:
# - IMG_70.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_70.mat:
# - IMG_71.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_71.mat:
# - IMG_72.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_72.mat:
# - IMG_73.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_73.mat:
# - IMG_74.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_74.mat:
# - IMG_75.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_75.mat:
# - IMG_76.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_76.mat:
# - IMG_77.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_77.mat:
# - IMG_78.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_78.mat:
# - IMG_79.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_79.mat:
# - IMG_8.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_8.mat:
# - IMG_80.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_80.mat:
# - IMG_81.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_81.mat:
# - IMG_82.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_82.mat:
# - IMG_83.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_83.mat:
# - IMG_84.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_84.mat:
# - IMG_85.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_85.mat:
# - IMG_86.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_86.mat:
# - IMG_87.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_87.mat:
# - IMG_88.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_88.mat:
# - IMG_89.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_89.mat:
# - IMG_9.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_9.mat:
# - IMG_90.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_90.mat:
# - IMG_91.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_91.mat:
# - IMG_92.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_92.mat:
# - IMG_93.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_93.mat:
# - IMG_94.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_94.mat:
# - IMG_95.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_95.mat:
# - IMG_96.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_96.mat:
# - IMG_97.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_97.mat:
# - IMG_98.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_98.mat:
# - IMG_99.jpg:  /content/drive/MyDrive/ground_truth/GT_IMG_99.mat:
# Finished preprocessing for /content/drive/MyDrive/images1. skipped: 0, Success: 316
# - IMG_1.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_1.mat:
# - IMG_10.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_10.mat:
# - IMG_100.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_100.mat:
# - IMG_101.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_101.mat:
# - IMG_102.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_102.mat:
# - IMG_103.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_103.mat:
# - IMG_104.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_104.mat:
# - IMG_105.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_105.mat:
# - IMG_106.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_106.mat:
# - IMG_107.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_107.mat:
# - IMG_108.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_108.mat:
# - IMG_109.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_109.mat:
# - IMG_11.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_11.mat:
# - IMG_110.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_110.mat:
# - IMG_111.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_111.mat:
# - IMG_112.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_112.mat:
# - IMG_113.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_113.mat:
# - IMG_114.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_114.mat:
# - IMG_115.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_115.mat:
# - IMG_116.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_116.mat:
# - IMG_117.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_117.mat:
# - IMG_118.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_118.mat:
# - IMG_119.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_119.mat:
# - IMG_12.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_12.mat:
# - IMG_120.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_120.mat:
# - IMG_121.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_121.mat:
# - IMG_122.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_122.mat:
# - IMG_123.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_123.mat:
# - IMG_124.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_124.mat:
# - IMG_125.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_125.mat:
# - IMG_126.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_126.mat:
# - IMG_127.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_127.mat:
# - IMG_128.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_128.mat:
# - IMG_129.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_129.mat:
# - IMG_13.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_13.mat:
# - IMG_130.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_130.mat:
# - IMG_131.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_131.mat:
# - IMG_132.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_132.mat:
# - IMG_133.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_133.mat:
# - IMG_134.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_134.mat:
# - IMG_135.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_135.mat:
# - IMG_136.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_136.mat:
# - IMG_137.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_137.mat:
# - IMG_138.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_138.mat:
# - IMG_139.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_139.mat:
# - IMG_14.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_14.mat:
# - IMG_140.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_140.mat:
# - IMG_141.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_141.mat:
# - IMG_142.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_142.mat:
# - IMG_143.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_143.mat:
# - IMG_144.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_144.mat:
# - IMG_145.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_145.mat:
# - IMG_146.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_146.mat:
# - IMG_147.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_147.mat:
# - IMG_148.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_148.mat:
# - IMG_149.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_149.mat:
# - IMG_15.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_15.mat:
# - IMG_150.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_150.mat:
# - IMG_151.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_151.mat:
# - IMG_152.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_152.mat:
# - IMG_153.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_153.mat:
# - IMG_154.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_154.mat:
# - IMG_155.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_155.mat:
# - IMG_156.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_156.mat:
# - IMG_157.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_157.mat:
# - IMG_158.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_158.mat:
# - IMG_159.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_159.mat:
# - IMG_16.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_16.mat:
# - IMG_160.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_160.mat:
# - IMG_161.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_161.mat:
# - IMG_162.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_162.mat:
# - IMG_163.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_163.mat:
# - IMG_164.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_164.mat:
# - IMG_165.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_165.mat:
# - IMG_166.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_166.mat:
# - IMG_167.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_167.mat:
# - IMG_168.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_168.mat:
# - IMG_169.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_169.mat:
# - IMG_17.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_17.mat:
# - IMG_170.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_170.mat:
# - IMG_171.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_171.mat:
# - IMG_172.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_172.mat:
# - IMG_173.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_173.mat:
# - IMG_174.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_174.mat:
# - IMG_175.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_175.mat:
# - IMG_176.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_176.mat:
# - IMG_177.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_177.mat:
# - IMG_178.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_178.mat:
# - IMG_179.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_179.mat:
# - IMG_18.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_18.mat:
# - IMG_180.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_180.mat:
# - IMG_181.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_181.mat:
# - IMG_182.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_182.mat:
# - IMG_183.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_183.mat:
# - IMG_184.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_184.mat:
# - IMG_185.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_185.mat:
# - IMG_186.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_186.mat:
# - IMG_187.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_187.mat:
# - IMG_188.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_188.mat:
# - IMG_189.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_189.mat:
# - IMG_19.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_19.mat:
# - IMG_190.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_190.mat:
# - IMG_191.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_191.mat:
# - IMG_192.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_192.mat:
# - IMG_193.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_193.mat:
# - IMG_194.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_194.mat:
# - IMG_195.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_195.mat:
# - IMG_196.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_196.mat:
# - IMG_197.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_197.mat:
# - IMG_198.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_198.mat:
# - IMG_199.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_199.mat:
# - IMG_2.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_2.mat:
# - IMG_20.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_20.mat:
# - IMG_200.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_200.mat:
# - IMG_201.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_201.mat:
# - IMG_202.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_202.mat:
# - IMG_203.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_203.mat:
# - IMG_204.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_204.mat:
# - IMG_205.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_205.mat:
# - IMG_206.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_206.mat:
# - IMG_207.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_207.mat:
# - IMG_208.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_208.mat:
# - IMG_209.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_209.mat:
# - IMG_21.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_21.mat:
# - IMG_210.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_210.mat:
# - IMG_211.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_211.mat:
# - IMG_212.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_212.mat:
# - IMG_213.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_213.mat:
# - IMG_214.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_214.mat:
# - IMG_215.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_215.mat:
# - IMG_216.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_216.mat:
# - IMG_217.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_217.mat:
# - IMG_218.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_218.mat:
# - IMG_219.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_219.mat:
# - IMG_22.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_22.mat:
# - IMG_220.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_220.mat:
# - IMG_221.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_221.mat:
# - IMG_222.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_222.mat:
# - IMG_223.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_223.mat:
# - IMG_224.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_224.mat:
# - IMG_225.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_225.mat:
# - IMG_226.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_226.mat:
# - IMG_227.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_227.mat:
# - IMG_228.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_228.mat:
# - IMG_229.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_229.mat:
# - IMG_23.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_23.mat:
# - IMG_230.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_230.mat:
# - IMG_231.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_231.mat:
# - IMG_232.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_232.mat:
# - IMG_233.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_233.mat:
# - IMG_234.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_234.mat:
# - IMG_235.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_235.mat:
# - IMG_236.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_236.mat:
# - IMG_237.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_237.mat:
# - IMG_238.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_238.mat:
# - IMG_239.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_239.mat:
# - IMG_24.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_24.mat:
# - IMG_240.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_240.mat:
# - IMG_241.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_241.mat:
# - IMG_242.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_242.mat:
# - IMG_243.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_243.mat:
# - IMG_244.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_244.mat:
# - IMG_245.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_245.mat:
# - IMG_246.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_246.mat:
# - IMG_247.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_247.mat:
# - IMG_248.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_248.mat:
# - IMG_249.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_249.mat:
# - IMG_25.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_25.mat:
# - IMG_250.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_250.mat:
# - IMG_251.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_251.mat:
# - IMG_252.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_252.mat:
# - IMG_253.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_253.mat:
# - IMG_254.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_254.mat:
# - IMG_255.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_255.mat:
# - IMG_256.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_256.mat:
# - IMG_257.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_257.mat:
# - IMG_258.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_258.mat:
# - IMG_259.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_259.mat:
# - IMG_26.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_26.mat:
# - IMG_260.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_260.mat:
# - IMG_261.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_261.mat:
# - IMG_262.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_262.mat:
# - IMG_263.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_263.mat:
# - IMG_264.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_264.mat:
# - IMG_265.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_265.mat:
# - IMG_266.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_266.mat:
# - IMG_267.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_267.mat:
# - IMG_268.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_268.mat:
# - IMG_269.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_269.mat:
# - IMG_27.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_27.mat:
# - IMG_270.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_270.mat:
# - IMG_271.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_271.mat:
# - IMG_272.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_272.mat:
# - IMG_273.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_273.mat:
# - IMG_274.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_274.mat:
# - IMG_275.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_275.mat:
# - IMG_276.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_276.mat:
# - IMG_277.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_277.mat:
# - IMG_278.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_278.mat:
# - IMG_279.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_279.mat:
# - IMG_28.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_28.mat:
# - IMG_280.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_280.mat:
# - IMG_281.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_281.mat:
# - IMG_282.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_282.mat:
# - IMG_283.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_283.mat:
# - IMG_284.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_284.mat:
# - IMG_285.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_285.mat:
# - IMG_286.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_286.mat:
# - IMG_287.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_287.mat:
# - IMG_288.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_288.mat:
# - IMG_289.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_289.mat:
# - IMG_29.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_29.mat:
# - IMG_290.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_290.mat:
# - IMG_291.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_291.mat:
# - IMG_292.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_292.mat:
# - IMG_293.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_293.mat:
# - IMG_294.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_294.mat:
# - IMG_295.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_295.mat:
# - IMG_296.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_296.mat:
# - IMG_297.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_297.mat:
# - IMG_298.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_298.mat:
# - IMG_299.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_299.mat:
# - IMG_3.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_3.mat:
# - IMG_30.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_30.mat:
# - IMG_300.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_300.mat:
# - IMG_301.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_301.mat:
# - IMG_302.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_302.mat:
# - IMG_303.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_303.mat:
# - IMG_304.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_304.mat:
# - IMG_305.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_305.mat:
# - IMG_306.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_306.mat:
# - IMG_307.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_307.mat:
# - IMG_308.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_308.mat:
# - IMG_309.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_309.mat:
# - IMG_31.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_31.mat:
# - IMG_310.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_310.mat:
# - IMG_311.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_311.mat:
# - IMG_312.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_312.mat:
# - IMG_313.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_313.mat:
# - IMG_314.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_314.mat:
# - IMG_315.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_315.mat:
# - IMG_316.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_316.mat:
# - IMG_32.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_32.mat:
# - IMG_33.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_33.mat:
# - IMG_34.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_34.mat:
# - IMG_35.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_35.mat:
# - IMG_36.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_36.mat:
# - IMG_37.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_37.mat:
# - IMG_38.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_38.mat:
# - IMG_39.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_39.mat:
# - IMG_4.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_4.mat:
# - IMG_40.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_40.mat:
# - IMG_41.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_41.mat:
# - IMG_42.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_42.mat:
# - IMG_43.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_43.mat:
# - IMG_44.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_44.mat:
# - IMG_45.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_45.mat:
# - IMG_46.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_46.mat:
# - IMG_47.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_47.mat:
# - IMG_48.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_48.mat:
# - IMG_49.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_49.mat:
# - IMG_5.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_5.mat:
# - IMG_50.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_50.mat:
# - IMG_51.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_51.mat:
# - IMG_52.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_52.mat:
# - IMG_53.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_53.mat:
# - IMG_54.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_54.mat:
# - IMG_55.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_55.mat:
# - IMG_56.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_56.mat:
# - IMG_57.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_57.mat:
# - IMG_58.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_58.mat:
# - IMG_59.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_59.mat:
# - IMG_6.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_6.mat:
# - IMG_60.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_60.mat:
# - IMG_61.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_61.mat:
# - IMG_62.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_62.mat:
# - IMG_63.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_63.mat:
# - IMG_64.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_64.mat:
# - IMG_65.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_65.mat:
# - IMG_66.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_66.mat:
# - IMG_67.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_67.mat:
# - IMG_68.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_68.mat:
# - IMG_69.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_69.mat:
# - IMG_7.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_7.mat:
# - IMG_70.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_70.mat:
# - IMG_71.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_71.mat:
# - IMG_72.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_72.mat:
# - IMG_73.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_73.mat:
# - IMG_74.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_74.mat:
# - IMG_75.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_75.mat:
# - IMG_76.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_76.mat:
# - IMG_77.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_77.mat:
# - IMG_78.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_78.mat:
# - IMG_79.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_79.mat:
# - IMG_8.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_8.mat:
# - IMG_80.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_80.mat:
# - IMG_81.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_81.mat:
# - IMG_82.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_82.mat:
# - IMG_83.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_83.mat:
# - IMG_84.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_84.mat:
# - IMG_85.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_85.mat:
# - IMG_86.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_86.mat:
# - IMG_87.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_87.mat:
# - IMG_88.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_88.mat:
# - IMG_89.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_89.mat:
# - IMG_9.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_9.mat:
# - IMG_90.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_90.mat:
# - IMG_91.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_91.mat:
# - IMG_92.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_92.mat:
# - IMG_93.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_93.mat:
# - IMG_94.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_94.mat:
# - IMG_95.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_95.mat:
# - IMG_96.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_96.mat:
# - IMG_97.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_97.mat:
# - IMG_98.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_98.mat:
# - IMG_99.jpg:  /content/drive/MyDrive/ground_truth1/GT_IMG_99.mat:
# Downloading: "https://download.pytorch.org/models/vit_b_16_swag-9ac1b537.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16_swag-9ac1b537.pth
# 100%|██████████| 331M/331M [00:05<00:00, 65.2MB/s]
